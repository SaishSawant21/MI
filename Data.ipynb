# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

# %%
dataset =pd.read_csv("/content/train.csv")
dataset.head()
# Out:
#    PassengerId     Sex   Age  \
# 0            1    male  22.0
# 1            2  female  38.0
# 2            3  female  26.0
# 3            4  female  35.0
# 4            5    male  35.0
#
#                                                 Name  Survived  Pclass  SibSp  \
# 0                            Braund, Mr. Owen Harris         0       3      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1      1
# 2                             Heikkinen, Miss. Laina         1       3      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1      1
# 4                           Allen, Mr. William Henry         0       3      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(x="Survived",data=dataset);#countplot to get the count / frquency ,

# %%
sns.countplot(x="Survived",hue="Sex",data=dataset)

# %%
dataset["Age"].plot.hist()

# %%
dataset["Fare"].plot.hist(bins=20,figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04c2c6faf6df> in <cell line: 1>()
# ----> 1 dataset["Fare"].plot.hist(bins=20,figsize=(10,5))
#
# NameError: name 'dataset' is not defined

# %%
dataset.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Sex          891 non-null    object
#  2   Age          714 non-null    float64
#  3   Name         891 non-null    object
#  4   Survived     891 non-null    int64
#  5   Pclass       891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(x="SibSp",data=dataset);

# %%
dataset.isnull()
# Out:
#      PassengerId    Sex    Age   Name  Survived  Pclass  SibSp  Parch  Ticket  \
# 0          False  False  False  False     False   False  False  False   False
# 1          False  False  False  False     False   False  False  False   False
# 2          False  False  False  False     False   False  False  False   False
# 3          False  False  False  False     False   False  False  False   False
# 4          False  False  False  False     False   False  False  False   False
# ..           ...    ...    ...    ...       ...     ...    ...    ...     ...
# 886        False  False  False  False     False   False  False  False   False
# 887        False  False  False  False     False   False  False  False   False
# 888        False  False   True  False     False   False  False  False   False
# 889        False  False  False  False     False   False  False  False   False
# 890        False  False  False  False     False   False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Sex              0
# Age            177
# Name             0
# Survived         0
# Pclass           0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(dataset.isnull(),yticklabels=False,cmap='viridis')

# %%
sns.boxplot(x="Pclass",y="Age",data=dataset)

# %%
dataset.drop("Cabin",axis=1,inplace=True)

# %%
dataset.head(5)
# Out:
#    PassengerId     Sex   Age  \
# 0            1    male  22.0
# 1            2  female  38.0
# 2            3  female  26.0
# 3            4  female  35.0
# 4            5    male  35.0
#
#                                                 Name  Survived  Pclass  SibSp  \
# 0                            Braund, Mr. Owen Harris         0       3      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1      1
# 2                             Heikkinen, Miss. Laina         1       3      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1      1
# 4                           Allen, Mr. William Henry         0       3      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
dataset.dropna(inplace=True)

# %%
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False)

# %%
dataset.isnull().sum()
# Out:
# PassengerId    0
# Sex            0
# Age            0
# Name           0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
sex=pd.get_dummies(dataset['Sex'])

# %%
embarked=pd.get_dummies(dataset['Embarked'])

# %%
pc1=pd.get_dummies(dataset['Pclass'])

# %%
embarked.head(5)
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
pc1=pd.get_dummies(dataset['Pclass'],drop_first=True)

# %%
pc1.head(5)
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
dataset.head(5)
# Out:
#    PassengerId     Sex   Age  \
# 0            1    male  22.0
# 1            2  female  38.0
# 2            3  female  26.0
# 3            4  female  35.0
# 4            5    male  35.0
#
#                                                 Name  Survived  Pclass  SibSp  \
# 0                            Braund, Mr. Owen Harris         0       3      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1      1
# 2                             Heikkinen, Miss. Laina         1       3      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1      1
# 4                           Allen, Mr. William Henry         0       3      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
dataset=pd.concat([dataset,Survived],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-efa144b67d3a> in <module>
# ----> 1 dataset=concat([dataset,sex,pc1,embarked],axis=1)
#
# NameError: name 'concat' is not defined

# %%
x=dataset.drop([Sex,Embarked,Pclass,Ticket],axis=1,inplace=np.True)

# %%
from pandas.core.internals import concat
dataset=pd.concat([dataset,sex,pc1,embarked],axis=1)

# %%
dataset.head(5)
# Out:
#    PassengerId     Sex   Age  \
# 0            1    male  22.0
# 1            2  female  38.0
# 2            3  female  26.0
# 3            4  female  35.0
# 4            5    male  35.0
#
#                                                 Name  Survived  Pclass  SibSp  \
# 0                            Braund, Mr. Owen Harris         0       3      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1      1
# 2                             Heikkinen, Miss. Laina         1       3      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1      1
# 4                           Allen, Mr. William Henry         0       3      0
#
#    Parch            Ticket     Fare Embarked  male  2  3  male
# 0      0         A/5 21171   7.2500        S     1  0  1     1
# 1      0          PC 17599  71.2833        C     0  0  0     0
# 2      0  STON/O2. 3101282   7.9250        S     0  0  1     0
# ...

# %%
sex.head(5)
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
sex=pd.get_dummies(dataset['Sex'],drop_first=True)

# %%
embarked=pd.get_dummies(dataset['Sex'],drop_first=True)

# %%
sex.head(5)
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1
